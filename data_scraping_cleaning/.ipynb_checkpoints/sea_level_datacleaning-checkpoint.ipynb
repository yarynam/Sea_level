# %%
import os
import glob
import pandas as pd
import numpy as np

path = "/Users/207423/Desktop/maybe/Newsapp_final-master/data_scraping_cleaning/all_20years"
allfiles = glob.glob(os.path.join(path,"*.csv"))
count = 1



for file_ in allfiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    df.columns = ['year', 'month', 'day', 'level'] #add column names
    df = df[(df.year >= 1994) & (df.year < 2015)] #filter 20 years
    
    name_string = file_.split('/') #add city name
    file_name = name_string[8]
    file_name = file_name.split('%')
    print file_name 
    latitude = file_name[0]
    longtitude = file_name[1]
    city_name = file_name[2].replace("_", " ")
    city_name = city_name.replace(".csv", "")
#     count +=1

    df = df.groupby('year') #group by year
    df = df["level"].mean().round(1).reset_index().rename(columns={'level': 'level_norm'})
    starting_value = df['level_norm'].iloc[0] #get starting value
    


    df["level_norm"] = df.level_norm - starting_value
    df["city"] = city_name
    df["latitude"] = latitude
    df["longtitude"] = longtitude
#     df["count"] = count
    
    df.index = df.index + 1 #start index from 1 for heatmap
    df.to_csv(file_, index=False)
    
    
    # get list of names
    last_value = df.level_norm.iloc[-1]
    print city_name,",", last_value
# Out:
# ['-0.43300', '-90.28300', 'Baltra_(Galapagos_Is.).csv']
# Baltra (Galapagos Is.) , 79.4
# ['-0.68700', '73.15200', 'Gan.csv']
# Gan , 41.6
# ['-0.75200', '-90.30700', 'Santa_Cruz_Galapagos.csv']
# Santa Cruz Galapagos , 71.9
# ['-10.60000', '141.92000', 'Booby_Is..csv']
# Booby Is. , 184.5
# ['-12.07100', '-77.17400', 'Callao.csv']
# Callao , 29.9
# ['-12.11700', '96.88300', 'Cocos_Is._(Keeling).csv']
# Cocos Is. (Keeling) , 143.8
# ['-12.46700', '130.85000', 'Darwin.csv']
# Darwin , 152.1
# ['-12.78300', '45.25000', 'Dzaoudzi_(Mayotte).csv']
# Dzaoudzi (Mayotte) , 113.4
# ['-13.40000', '48.28000', 'Nosy-Be.csv']
# Nosy-Be , 69.6
# ['-13.41700', '-76.13300', 'Pisco.csv']
# Pisco , 83.4
# ['-13.81700', '-171.75000', 'Apia.csv']
# Apia , 152.3
# ['-13.83000', '136.50000', 'Groote_Eylandt.csv']
# Groote Eylandt , 171.3
# ['-14.27700', '-170.69100', 'Pago_Pago.csv']
# Pago Pago , 193.5
# ['-17.00000', '-72.11700', 'Matarani.csv']
# Matarani , 147.4
# ['-17.53300', '-149.56700', 'Papeete.csv']
# Papeete , 85.1
# ['-17.75000', '168.28000', 'Port_Vila_VU_(Villa).csv']
# Port Vila VU (Villa) , 42.5
# ['-18.00100', '122.21900', 'Broome.csv']
# Broome , 143.2
# ['-19.28000', '147.06000', 'Cape_Ferguson.csv']
# Cape Ferguson , 96.6
# ['-19.66800', '63.41800', 'Rodrigues_MU_(Port_Mathurin).csv']
# Rodrigues MU (Port Mathurin) , 165.8
# ['-2.04200', '147.37000', 'Lombrum_Manus_Is..csv']
# Lombrum Manus Is. , 131.4
# ['-2.20900', '-80.90200', 'La_Libertad.csv']
# La Libertad , 58.7
# ['-20.15500', '57.49500', 'Port_Louis.csv']
# Port Louis , 78.0
# ['-20.93000', '55.30000', 'Pte_Des_Galets_(Reunion_Is.).csv']
# Pte Des Galets (Reunion Is.) , 168.6
# ['-21.15000', '-175.18000', "Tongatapu_(Nuku'_alofa).csv"]
# Tongatapu (Nuku' alofa) , 174.6
# ['-21.20000', '-159.78300', 'Rarotonga.csv']
# Rarotonga , 59.3
# ['-22.28500', '166.43300', 'Noumea.csv']
# Noumea , 57.0
# ['-22.93000', '14.50000', 'Walvis_Bay.csv']
# Walvis Bay , 119.5
# ['-23.13300', '-134.97000', 'Rikitea.csv']
# Rikitea , 34.3
# ['-23.17000', '150.78000', 'Rosslyn_Bay.csv']
# Rosslyn Bay , 92.4
# ['-23.65000', '-70.41700', 'Antofagasta.csv']
# Antofagasta , -39.1
# ['-24.77000', '152.38000', 'Burnett_Heads_(Bundaberg).csv']
# Burnett Heads (Bundaberg) , 136.1
# ['-26.25800', '-80.12400', 'San_Felix.csv']
# San Felix , -102.2
# ['-26.63000', '15.15000', 'Luderitz.csv']
# Luderitz , 134.4
# ['-27.15300', '-109.44800', 'Pascua_Is._(Easter_Is.).csv']
# Pascua Is. (Easter Is.) , -37.1
# ['-27.36700', '153.16700', 'Brisbane.csv']
# Brisbane , 93.9
# ['-28.79000', '32.08000', "Richard's_Bay.csv"]
# Richard's Bay , 56.7
# ['-29.25000', '16.86700', 'Port_Nolloth.csv']
# Port Nolloth , 68.6
# ['-29.83300', '31.03300', 'Durban.csv']
# Durban , 66.0
# ['-31.83000', '115.74000', 'Hillarys.csv']
# Hillarys , 164.4
# ['-32.05000', '115.73300', 'Fremantle.csv']
# Fremantle , 138.0
# ['-32.14900', '133.64100', 'Thevenard.csv']
# Thevenard , 96.7
# ['-33.00000', '17.93000', 'Saldanha_(Saldahna_Bay).csv']
# Saldanha (Saldahna Bay) , 53.2
# ['-33.00000', '27.90000', 'East_London.csv']
# East London , 40.8
# ['-33.03300', '-71.61700', 'Valparaiso.csv']
# Valparaiso , -47.3
# ['-33.61700', '-78.83300', 'Juan_Fernandez.csv']
# Juan Fernandez , 83.6
# ['-33.85000', '151.23300', 'Fort_Denison_(Sydney).csv']
# Fort Denison (Sydney) , 77.4
# ['-33.87100', '121.89500', 'Esperance.csv']
# Esperance , 107.2
# ['-33.90000', '18.41700', 'Granger_Bay.csv']
# Granger Bay , 90.1
# ['-33.96700', '25.63300', 'Port_Elizabeth.csv']
# Port Elizabeth , 88.8
# ['-34.08000', '23.05000', 'Knysna.csv']
# Knysna , 42.0
# ['-34.18300', '18.43300', "Simon's_Bay_(Simonstown).csv"]
# Simon's Bay (Simonstown) , 80.0
# ['-34.18300', '22.15000', 'Mossel_Bay.csv']
# Mossel Bay , 237.3
# ['-35.83300', '174.50000', 'Mardsen_Point.csv']
# Mardsen Point , 145.2
# ['-37.65000', '176.18300', 'Tauranga.csv']
# Tauranga , 136.6
# ['-38.34300', '141.61300', 'Portland.csv']
# Portland , 51.3
# ['-39.05000', '174.03300', 'Taranaki.csv']
# Taranaki , 118.5
# ['-39.48000', '176.92000', 'Napier.csv']
# Napier , 88.8
# ['-4.06700', '39.39000', 'Mombasa.csv']
# Mombasa , 89.1
# ['-4.62000', '-81.28000', 'Talara.csv']
# Talara , 118.9
# ['-4.67200', '55.52800', 'Pointe_La_Rue_Mahe_Is._(Port_Victoria).csv']
# Pointe La Rue Mahe Is. (Port Victoria) , 85.5
# ['-41.05000', '145.92000', 'Burnie.csv']
# Burnie , 59.2
# ['-41.25000', '173.27000', 'Nelson.csv']
# Nelson , 116.3
# ['-41.28300', '174.78300', 'Wellington_Harbour.csv']
# Wellington Harbour , 115.7
# ['-41.86000', '-74.35000', 'Puerto_Montt.csv']
# Puerto Montt , -19.7
# ['-42.54600', '147.93300', 'Spring_Bay.csv']
# Spring Bay , 51.1
# ['-44.38000', '171.25000', 'Timaru.csv']
# Timaru , 90.2
# ['-45.82000', '170.65000', 'Port_Chalmers.csv']
# Port Chalmers , 41.7
# ['-46.60000', '168.35000', 'Bluff_Harbour.csv']
# Bluff Harbour , 33.3
# ['-5.08300', '-81.16700', 'Paita.csv']
# Paita , 116.3
# ['-51.70000', '-57.82000', 'Port_Stanley.csv']
# Port Stanley , 87.8
# ['-6.15000', '39.18300', 'Zanzibar.csv']
# Zanzibar , 85.7
# ['-6.93500', '-80.72000', 'Lobos_de_Afuera.csv']
# Lobos de Afuera , 35.0
# ['-8.53300', '179.20000', 'Funafuti.csv']
# Funafuti , 68.1
# ['-8.92200', '-140.09500', 'Nuku_Hiva_(Marquesas_Is.).csv']
# Nuku Hiva (Marquesas Is.) , 124.2
# ['-9.01700', '-158.06700', 'Penrhyn.csv']
# Penrhyn , 64.1
# ['-9.43300', '159.95000', 'Honiara.csv']
# Honiara , 176.5
# ['0.53300', '166.93000', 'Nauru.csv']
# Nauru , 179.1
# ['1.10000', '154.78300', 'Kapingamarangi_(Caroline_Is.).csv']
# Kapingamarangi (Caroline Is.) , 100.6
# ['1.35000', '172.91700', 'Betio_(Tarawa).csv']
# Betio (Tarawa) , 62.5
# ['1.43000', '125.20000', 'Manado_(Bitung).csv']
# Manado (Bitung) , 111.0
# ['1.46700', '103.83300', 'Keppel_Harbour_(Tanjong_Pagar).csv']
# Keppel Harbour (Tanjong Pagar) , 82.1
# ['1.83000', '-78.73300', 'Tumaco.csv']
# Tumaco , 64.8
# ['1.98300', '-157.46700', 'Christmas_Is._(Line_Is.).csv']
# Christmas Is. (Line Is.) , 67.8
# ['10.40000', '-75.55000', 'Cartagena.csv']
# Cartagena , 147.5
# ['11.80000', '99.82000', 'Ko_Lak.csv']
# Ko Lak , 161.6
# ['13.16100', '123.75800', 'Legaspi_(Albay).csv']
# Legaspi (Albay) , 72.7
# ['13.59000', '144.87000', 'Guam_(Apra_Harbour}.csv']
# Guam (Apra Harbour} , 59.2
# ['14.64000', '121.08000', 'Manila.csv']
# Manila , 203.9
# ['14.68300', '-60.93300', 'Fort-de-France_(Le_Robert).csv']
# Fort-de-France (Le Robert) , 55.8
# ['15.22700', '145.74200', 'Saipan.csv']
# Saipan , 22.3
# ['16.73300', '-169.53300', 'Johnston_Is..csv']
# Johnston Is. , -13.7
# ['16.93500', '54.00700', 'Salalah.csv']
# Salalah , 41.0
# ['17.76000', '-64.75000', 'Lime_Tree_Bay_(St._Croix).csv']
# Lime Tree Bay (St. Croix) , 47.6
# ['17.96700', '-67.04700', 'Magueyes_Is..csv']
# Magueyes Is. , 60.7
# ['18.33000', '-64.92000', 'Charlotte_Amalie.csv']
# Charlotte Amalie , 49.5
# ['18.46200', '-66.11700', 'San_Juan_Puerto_Rico.csv']
# San Juan Puerto Rico , 47.7
# ['19.28300', '166.61700', 'Wake_Is..csv']
# Wake Is. , 18.4
# ['19.73000', '-155.07000', 'Hilo.csv']
# Hilo , 71.4
# ['20.03300', '-155.83000', 'Kawaihae.csv']
# Kawaihae , 163.6
# ['20.89800', '-156.46700', 'Kahului_Harbor.csv']
# Kahului Harbor , 55.9
# ['21.30000', '-157.86000', 'Honolulu.csv']
# Honolulu , 36.4
# ['21.43300', '-157.78000', 'Mokuoloe_Is..csv']
# Mokuoloe Is. , 33.6
# ['21.96700', '-159.35000', 'Nawiliwili_Bay.csv']
# Nawiliwili Bay , 64.2
# ['22.60000', '114.22000', 'Quarry_Bay_(Hong_Kong).csv']
# Quarry Bay (Hong Kong) , 52.9
# ['22.61700', '120.28300', 'Kaohsiung.csv']
# Kaohsiung , 9.7
# ['24.33300', '124.17000', 'Ishigaki.csv']
# Ishigaki , 8.6
# ['24.55300', '-81.80800', 'Key_West.csv']
# Key West , 88.3
# ['25.15000', '121.75000', 'Keelung.csv']
# Keelung , -1.2
# ['26.06000', '-97.22000', 'Port_Isabel.csv']
# Port Isabel , 72.5
# ['26.22000', '127.67000', 'Naha.csv']
# Naha , 92.7
# ['27.08000', '142.18000', 'Chichijima.csv']
# Chichijima , -20.1
# ['27.58000', '-97.21700', 'Corpus_Christi.csv']
# Corpus Christi , 50.2
# ['27.77000', '-82.63000', 'St._Petersburg.csv']
# St. Petersburg , 94.7
# ['27.98000', '-82.83000', 'Clearwater_Beach.csv']
# Clearwater Beach , -48.8
# ['28.02000', '-97.05000', 'Rockport.csv']
# Rockport , 148.8
# ['28.21700', '-177.36700', 'Midway_Is._(Sand_Is.).csv']
# Midway Is. (Sand Is.) , 99.7
# ['29.27000', '-89.96000', 'Grand_Isle.csv']
# Grand Isle , 121.0
# ['29.33000', '-94.74000', 'Galveston_(Pier_21).csv']
# Galveston (Pier 21) , 78.2
# ['29.73000', '-93.87000', 'Sabine_Pass.csv']
# Sabine Pass , 55.8
# ['3.90000', '-77.10000', 'Buenaventura.csv']
# Buenaventura , 96.8
# ['30.15200', '-85.67000', 'Panama_City.csv']
# Panama City , 56.6
# ['30.40300', '-87.21200', 'Pensacola.csv']
# Pensacola , 81.0
# ['30.68000', '-81.47000', 'Fernandina_Beach.csv']
# Fernandina Beach , 48.9
# ['31.56700', '131.41700', 'Aburatsu.csv']
# Aburatsu , 41.6
# ['32.03300', '-80.90200', 'Fort_Pulaski.csv']
# Fort Pulaski , 146.9
# ['32.22000', '-64.70000', 'Bermuda_St._Georges_Is..csv']
# Bermuda St. Georges Is. , 98.6
# ['32.71300', '-117.17300', 'San_Diego.csv']
# San Diego , 108.5
# ['32.73300', '129.86700', 'Nagasaki.csv']
# Nagasaki , 83.2
# ['32.78200', '-79.92500', 'Charleston.csv']
# Charleston , 129.5
# ['32.86700', '-117.25000', 'La_Jolla.csv']
# La Jolla , 138.4
# ['33.13000', '135.78000', 'Kushimoto.csv']
# Kushimoto , 99.1
# ['33.13300', '137.10000', 'Tokai.csv']
# Tokai , 90.2
# ['33.71700', '-118.27200', 'Los_Angeles.csv']
# Los Angeles , 70.4
# ['34.00800', '-118.50000', 'Santa_Monica.csv']
# Santa Monica , 80.9
# ['34.23000', '-77.59000', 'Wilmington.csv']
# Wilmington , 137.2
# ['34.47000', '-120.68000', 'Harvest_Oil_Platform.csv']
# Harvest Oil Platform , 36.1
# ['34.68300', '137.61700', 'Maisaka.csv']
# Maisaka , -49.3
# ['34.90000', '132.07000', 'Hamada_(Hampton).csv']
# Hamada (Hampton) , 77.5
# ['34.91700', '139.83300', 'Mera.csv']
# Mera , 89.1
# ['35.17000', '-120.75000', 'Port_San_Luis.csv']
# Port San Luis , 95.3
# ['35.18300', '-75.75000', 'Duck_Pier.csv']
# Duck Pier , 143.7
# ['36.13000', '-5.35000', 'Gibraltar.csv']
# Gibraltar , -109.9
# ['36.60500', '-121.88800', 'Monterey_Harbor.csv']
# Monterey Harbor , 90.5
# ['36.77000', '137.22000', 'Toyama.csv']
# Toyama , 52.2
# ['36.97000', '-76.11000', 'Chesapeake_Bay.csv']
# Chesapeake Bay , 159.3
# ['37.73000', '-25.68000', 'Ponta_Delgada.csv']
# Ponta Delgada , 83.5
# ['37.80000', '-122.46700', 'San_Francisco_(Fort_Point).csv']
# San Francisco (Fort Point) , 104.4
# ['38.78000', '-75.10000', 'Lewes.csv']
# Lewes , 131.2
# ['38.97000', '-74.97000', 'Cape_May.csv']
# Cape May , 134.0
# ['39.02000', '141.75000', 'Ofunato.csv']
# Ofunato , -75.9
# ['39.35000', '-74.42000', 'Atlantic_City.csv']
# Atlantic City , 150.0
# ['4.20000', '73.52700', 'Male_(Hulhule).csv']
# Male (Hulhule) , 64.8
# ['40.70000', '-74.02000', 'New_York.csv']
# New York , 139.1
# ['40.76700', '-124.21700', 'Humboldt_Bay.csv']
# Humboldt Bay , 159.2
# ['41.07000', '-71.86000', 'Montauk.csv']
# Montauk , 108.9
# ['41.28000', '-70.10000', 'Nantucket_Is..csv']
# Nantucket Is. , 126.5
# ['41.37000', '-72.10000', 'New_London.csv']
# New London , 118.2
# ['41.51000', '-71.33300', 'Newport.csv']
# Newport , 107.5
# ['41.53000', '-70.67000', 'Woods_Hole.csv']
# Woods Hole , 127.8
# ['41.74500', '-124.18300', 'Crescent_City.csv']
# Crescent City , 14.9
# ['41.78300', '140.73300', 'Hakodate.csv']
# Hakodate , -58.1
# ['42.35000', '-71.05000', 'Boston.csv']
# Boston , 134.5
# ['42.97000', '144.38300', 'Kushiro.csv']
# Kushiro , 107.7
# ['43.28000', '5.35000', 'Marseille.csv']
# Marseille , 160.8
# ['43.34500', '-124.32200', 'Charleston.csv']
# Charleston , 63.8
# ['43.66000', '-70.25000', 'Portland.csv']
# Portland , 94.5
# ['44.01700', '144.28300', 'Abashiri.csv']
# Abashiri , 43.9
# ['44.62500', '-124.04300', 'South_Beach.csv']
# South Beach , 74.4
# ['44.68000', '-63.61000', 'Halifax.csv']
# Halifax , 86.0
# ['44.91000', '-66.99000', 'Eastport.csv']
# Eastport , 97.6
# ['45.40000', '141.68000', 'Wakkanai.csv']
# Wakkanai , 28.2
# ['46.22000', '-123.76700', 'Astoria_(Tongue_Point).csv']
# Astoria (Tongue Point) , 84.9
# ['46.70500', '-123.95900', 'Toke_Point_(Willapa_Bay).csv']
# Toke Point (Willapa Bay) , -37.0
# ['47.40000', '-52.68000', "St._John's_Newfoundland.csv"]
# St. John's Newfoundland , -1.4
# ['48.12500', '-123.44000', 'Port_Angeles.csv']
# Port Angeles , 42.0
# ['48.36800', '-124.61700', 'Neah_Bay.csv']
# Neah Bay , 3.7
# ['48.38300', '-4.50000', 'Brest.csv']
# Brest , 85.7
# ['48.42000', '-123.37000', 'Victoria.csv']
# Victoria , 60.7
# ['49.15000', '-125.91700', 'Tofino.csv']
# Tofino , 63.7
# ['5.28500', '-52.58500', 'Ile_Royale.csv']
# Ile Royale , 64.8
# ['51.86700', '-176.63300', 'Adak.csv']
# Adak , 9.7
# ['53.87000', '8.72000', 'Cuxhaven.csv']
# Cuxhaven , -21.3
# ['53.88300', '-166.53300', 'Unalaska_(Dutch_Harbor).csv']
# Unalaska (Dutch Harbor) , 22.6
# ['54.31700', '-130.31700', 'Prince_Rupert.csv']
# Prince Rupert , 46.5
# ['55.33300', '-131.63000', 'Ketchikan.csv']
# Ketchikan , -55.2
# ['55.33700', '-160.50200', 'Sand_Point.csv']
# Sand Point , 106.8
# ['56.54000', '-61.69000', 'Nain.csv']
# Nain , -175.4
# ['57.05200', '-135.34200', 'Sitka.csv']
# Sitka , -71.1
# ['57.68300', '11.80000', 'Goteborg-Torshamnen_(Gothenburg).csv']
# Goteborg-Torshamnen (Gothenburg) , -20.7
# ['57.73200', '-152.51200', 'Kodiak.csv']
# Kodiak , -126.7
# ['59.32000', '18.08000', 'Stockholm.csv']
# Stockholm , -123.0
# ['59.43700', '-151.71700', 'Seldovia.csv']
# Seldovia , -129.2
# ['59.54800', '-139.73500', 'Yakutat.csv']
# Yakutat , -301.3
# ['6.86700', '99.76700', 'Langkawi.csv']
# Langkawi , 115.7
# ['60.11900', '-149.42700', 'Seward.csv']
# Seward , -65.9
# ['60.55800', '-145.75300', 'Cordova.csv']
# Cordova , 5.6
# ['61.12500', '-146.36200', 'Valdez.csv']
# Valdez , -161.5
# ['61.93300', '5.11700', 'Maloy.csv']
# Maloy , 56.7
# ['64.50000', '-165.43000', 'Nome_AK_(Norton_Sound).csv']
# Nome AK (Norton Sound) , 465.3
# ['64.86700', '11.25000', 'Rorvik.csv']
# Rorvik , -40.8
# ['69.32000', '16.15000', 'Andenes.csv']
# Andenes , -12.5
# ['7.11700', '171.36700', 'Majuro.csv']
# Majuro , 85.5
# ['7.32800', '134.45000', 'Malakal.csv']
# Malakal , 103.2
# ['70.34000', '31.03000', 'Vardoe.csv']
# Vardoe , -19.0
# ['70.38800', '-148.51000', 'Prudhoe_Bay.csv']
# Prudhoe Bay , 23.2
# ['70.98000', '25.98000', 'Honningsvag.csv']
# Honningsvag , -8.9
# ['78.93000', '11.95000', 'Ny-Alesund.csv']
# Ny-Alesund , -221.7
# ['8.73700', '167.73800', 'Kwajalein.csv']
# Kwajalein , 112.6
# ['8.97000', '-79.57000', 'Balboa.csv']
# Balboa , 12.1
# ['9.36700', '-79.88300', 'Cristobal.csv']
# Cristobal , -25.0
# ['9.51400', '138.12500', 'Yap.csv']
# Yap , 131.1
